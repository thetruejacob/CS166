# %% [markdown]
# The number of edges in a complete graph made of  n  nodes.
# $$ \sum_{i=1}^{n-1}i = n(n-1)/2 $$
#
# The number of edges in a regular graph made of n nodes each of which has degree k
# $$ nk/2$$

# %%
import networkx as nx
from pylab import *

g1 = nx.complete_graph(4)
nx.draw(g1)
show()

# %%
g2 = nx.complete_graph(5)
nx.draw(g2)

# %%
g3 = nx.complete_bipartite_graph(2, 3)
nx.draw(g3)

# %%
g4 = nx.complete_bipartite_graph(3, 3)
nx.draw(g4)

# %% [markdown]
# Sayama Exercise 15.4. Every connected tree graph made of  n  nodes has exactly  n  – 1 edges. Explain why.
#
# You can rearrange the tree into a line with n nodes and still preserve the number of nodes and edges, because it is clear that each node has exactly 1 edge connecting it to the next. Clearly there are n-1 edges.

# %%
g5 = nx.hypercube_graph(4)
nx.draw(g5)
# Out:
# /Users/jacob/miniconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
g6 = nx.circular_ladder_graph(5)
nx.draw(g6)

# %%
g7 = nx.barbell_graph(20, 1)
nx.draw(g7)

# %%
g8 = nx.wheel_graph(100)
nx.draw(g8)
# Out:
# /Users/jacob/miniconda3/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %% [markdown]
# Imagine a graph representing hockey players and hockey clubs. Each node is either aplayer or a club and each edge indicates that a player has played for that club at somepoint in the past. Explain why this graph is a bipartite graph.
#
# Because there are two distinct classes of nodes: hockey players and hockey clubs. Since an edge indicates a player has played at a club, edges must necessarily join exactly one player with one club. All edges must therefore 'cross the partition'.
